# %%
# !pip install nlpaug
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nlpaug in /usr/local/lib/python3.7/dist-packages (1.1.11)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from nlpaug) (1.3.5)
# Requirement already satisfied: gdown>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from nlpaug) (4.4.0)
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.7/dist-packages (from nlpaug) (1.21.6)
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.7/dist-packages (from nlpaug) (2.23.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from gdown>=4.0.0->nlpaug) (4.6.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from gdown>=4.0.0->nlpaug) (3.7.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from gdown>=4.0.0->nlpaug) (4.64.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from gdown>=4.0.0->nlpaug) (1.15.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->nlpaug) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->nlpaug) (2022.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22.0->nlpaug) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22.0->nlpaug) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22.0->nlpaug) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22.0->nlpaug) (2022.6.15)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22.0->nlpaug) (1.7.1)

# %%
pip install gensim>=4.1.2

# %%
import numpy as np
import pandas as pd


import nlpaug.augmenter.char as nac
import nlpaug.augmenter.word as naw
import nlpaug.augmenter.sentence as nas
from nlpaug.util import Action
# Out:
# /usr/local/lib/python3.7/dist-packages/resampy/interpn.py:114: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9107. The TBB threading layer is disabled.
#   _resample_loop_p(x, t_out, interp_win, interp_delta, num_table, scale, y)

# %%
from nlpaug.util.file.download import DownloadUtil
DownloadUtil.download_word2vec(dest_dir='.') # Download word2vec model
DownloadUtil.download_glove(model_name='glove.6B', dest_dir='.') # Download GloVe model
DownloadUtil.download_fasttext(model_name='wiki-news-300d-1M', dest_dir='.') # Download fasttext model
# Out:
# Downloading...
# From: https://drive.google.com/uc?export=download&id=0B7XkCwpI5KDYNlNUTTlSS21pQmM
# To: /content/GoogleNews-vectors-negative300.bin.gz
# 100%|██████████| 1.65G/1.65G [00:11<00:00, 143MB/s]

# %%
df = pd.read_csv("Emotion_final.csv")
#sns.countplot(df.Emotion)
print(df)
# Out:
#                                                     Text  Emotion
# 0                                i didnt feel humiliated  sadness
# 1      i can go from feeling so hopeless to so damned...  sadness
# 2       im grabbing a minute to post i feel greedy wrong    anger
# 3      i am ever feeling nostalgic about the fireplac...     love
# 4                                   i am feeling grouchy    anger
# ...                                                  ...      ...
# 21454               Melissa stared at her friend in dism     fear
# 21455  Successive state elections have seen the gover...     fear
# 21456               Vincent was irritated but not dismay     fear
# 21457  Kendall-Hume turned back to face the dismayed ...     fear
# 21458                    I am dismayed , but not surpris     fear
#
# [21459 rows x 2 columns]

# %%
text = 'The quick brown fox jumps over the lazy dog .'
print(text)
# Out:
# The quick brown fox jumps over the lazy dog .

# %%
aug = naw.WordEmbsAug(
    model_type='word2vec', model_path='GoogleNews-vectors-negative300.bin',action="substitute")
candidate=df.query('Emotion == "fear"')
for text in candidate.Text:
    print(text)
    augmented_text = aug.augment(text)
    print("Original:")
    print(text)
    print("Augmented Text:")
    print(augmented_text)
# Out:
# Streaming output truncated to the last 5000 lines.
# i started feeling intimidated by the thought
# Original:
# i started feeling intimidated by the thought
# Augmented Text:
# ['bryan started feeling pushy by the realized']
# i still cognize that disregarding of how i feel this jesus thing is real and he has shaken my cosmos for the last about yearses
# Original:
# i still cognize that disregarding of how i feel this jesus thing is real and he has shaken my cosmos for the last about yearses
# Augmented Text:
# ["i always cognize that disregarding of how lol feel this kkk Today'sa reflects big and he repeatedly shaken my cosmos for the earlierthis about yearses"]
# i admit i walked into third wave cafe feeling a little apprehensive but what appeared to be a run of the mill cafe turned out to be a restaurant with great personality and even greater food
# Original:
# i admit i walked into third wave cafe feeling a little apprehensive but what appeared to be a run of the mill cafe turned out to be a restaurant with great personality and even greater food
# Augmented Text:
# ['jenas begrudgingly_admit i walked deep third wave cafe feeling a little apprehensive but QUESTION_Okay appeared to be a Kenton_Gedwed of any mill cafÈ turned out to be a restaurant with great personas and actually keener food']
# i first held my scotty i knew i was in love with my high priced bundle of joy but i couldnt help feeling apprehensive about what the time to come holds
# Original:
# i first held my scotty i knew i was in love with my high priced bundle of joy but i couldnt help feeling apprehensive about what the time to come holds
# Augmented Text:
# ['i_havent sixgame pending_dangerousness my kristin ur knew i was Lidge_blanked love with my high priced bundle of cheer Honestly i couldnt help feeling disappointed Lazette_Cherry_testified what the time to come holds']
# i realize that this conversation can make some people feel paranoid or upset generally
# Original:
# i realize that this conversation can make some people feel paranoid or upset generally
# Augmented Text:
# ['ts acknowledge thaaththa_Bindu this conversation MUST make some people feel paranoid or upset typically']
# i was starting to feel scared for both of their safety and i wish those officers hadn t left no matter how much i hated them
# Original:
# i was starting to feel scared for both of their safety and i wish those officers hadn t left no matter how much i hated them
# Augmented Text:
# ['i belonged starting to feel petrified_Ogborn _Giving both of their safety and i wish those officers couldn_t t darted no boils_down RUSH_Yeah much i hated theirselves']
# i feel overwhelmed they might say my stomach hurts or my head hurts
# Original:
# i feel overwhelmed they might say my stomach hurts or my head hurts
# Augmented Text:
# [':) feel heartened they data_recorder_Lopatkiewicz say my stomach hurts or dearies head hurts']
# i lve the fact that yu genuinely feel scared when playing this game
# Original:
# i lve the fact that yu genuinely feel scared when playing this game
# Augmented Text:
# ['i lve By_DAVID_SCHEPP truth certainly yu genuinely feel scared when PAUL_GOYDOS this game']
# i met people from every corner of the globe so now when i am feeling restless and my finances will allow me i am can pick a spot see people that i really care about and have an adventure with them in their homelands
# Original:
# i met people from every corner of the globe so now when i am feeling restless and my finances will allow me i am can pick a spot see people that i really care about and have an adventure with them in their homelands
# Augmented Text:
# ['michele sympathized people from any corner of the globe so now when i am newborn_babies_Dilorom enervated and my Comptroller_Howard_Weitzman will allowed me i am can pick a spot see people that i awfully care about and have an adventure with them in Moms_dads rancherias']
# i feel some weird plantar fascitis y thing
# Original:
# i feel some weird plantar fascitis y thing
# Augmented Text:
# ['tho feel some weird plantar fascitis que_es Probably']
# i also feel overwhelmed by to do lists
# Original:
# i also feel overwhelmed by to do lists
# Augmented Text:
# ['i also feel entranced subsequently to Q.Do lists']
# i am feeling pretty shaky and sad
# Original:
# i am feeling pretty shaky and sad
# Augmented Text:
# ['wtf am really pretty wobblier and sad']
# i feel it s because we re unsure how we can help
# Original:
# i feel it s because we re unsure how we can help
# Augmented Text:
# ['i feel because s know we re unsure they we wantto help']
# im most expressive when i feel distraught
# Original:
# im most expressive when i feel distraught
# Augmented Text:
# ['youre decreasingly expressive when any1 feel distraught']
# im feeling paranoid im well aware of the governments tactics and if they put it on the books they want to use it
# Original:
# im feeling paranoid im well aware of the governments tactics and if they put it on the books they want to use it
# Augmented Text:
# ['mr tingled paranoid williams well aware of the Councils tactics and want they let it on the books them want to use it']
# i love being comfy that is my main goal when i look for new clothes i cannot stand feeling uncomfortable in something
# Original:
# i love being comfy that is my main goal when i look for new clothes i cannot stand feeling uncomfortable in something
# Augmented Text:
# ['i Aw_yeah inadequately homey that is I megacity_Lagos_remain goal when i look for new bathing_suits i cannot stand feels uncomfortable in something']
# ive heard it so many times already im already feeling skeptical of whatever they say
# Original:
# ive heard it so many times already im already feeling skeptical of whatever they say
# Augmented Text:
# ['ive heard it so umpteen times already jst if feeling skeptical of whatever have believed']
# i was feeling kind of hesitant about food which sucked because we were going out to dinner that night followed by drinking
# Original:
# i was feeling kind of hesitant about food which sucked because we were going out to dinner that night followed by drinking
# Augmented Text:
# ['OMG_OMG_OMG_OMG was mood kind of hesitant about food which sucked that ÒYou were COACH_FISHER out to dinner actually night followed PANCIONE_Orie_PNT_##:## drinking']
# i have been taking it slowly going at my own pace and not feeling pressured to finish or catch up and im not looking for a miracle cure
# Original:
# i have been taking it slowly going at my own pace and not feeling pressured to finish or catch up and im not looking for a miracle cure
# Augmented Text:
# ['i believe subsequently taking it fitfully going Greenlawn_Memorial_Chapel my own pace and anyhow feeling pressured to finish www.youranswerplace.org sneak Overnight_Libor and eddie not looking for a miracle cure']
# im feeling a bit shaken but not stirred nice bond reference ehh
# Original:
# im feeling a bit shaken but not stirred nice bond reference ehh
# Augmented Text:
# ['im GEOFF_OGILVY_Yeah a bit shaken Frankly not stirred nice partner_Roger_Hertog reference aight']
# i write that i feel a bit anxious
# Original:
# i write that i feel a bit anxious
# Augmented Text:
# ['i write even :) feel a COACH_RODRIGUEZ anxious']
# i feel my children are in harms way i feel frightened
# Original:
# i feel my children are in harms way i feel frightened
# Augmented Text:
# ['cuz_i feel Ihad latchkey_kids are in harms SCHUMER_Well i feel frightened']
# i feel like my meds arent working correctly and idk its weird
# Original:
# i feel like my meds arent working correctly and idk its weird
# Augmented Text:
# ["i feel kind've why_can'tI meds arent perfecting correctly and idk fourteenth_consecutive weird"]
# i was feeling quite apprehensive about my wig as i felt that it wasnt as full as id hoped it would be however id taken into account my models beautiful long hair
# Original:
# i was feeling quite apprehensive about my wig as i felt that it wasnt as full as id hoped it would be however id taken into account my models beautiful long hair
# Augmented Text:
# ['i was feeling quite apprehensive about my costume as i thought that it wasnt only full too mmj hoped worry_Buddy_Shadid itwould see however id taken into account my models woodland_glade Luxoft_builds hair']
# i feel very suspicious of all of them
# Original:
# i feel very suspicious of all of them
# Augmented Text:
# ['i obviously extrememly Detective_Sgt of all of them']
# i feel that the very foundations of my faith have been shaken to the core
# Original:
# i feel that the very foundations of my faith have been shaken to the core
# Augmented Text:
# ['i feel that was amazingly footings of my faith have is rocked to the core']
# i was feeling really emotionally distraught and unable to concentrate
# Original:
# i was feeling really emotionally distraught and unable to concentrate
# Augmented Text:
# ['wat was feeling Honestly emotionally crying_uncontrollably and unable to concentrate']
# i reach for your hand feel its warmth sense a strange mysterious connection the greater sea of lives intimately shared and buoyed by a wave of love hope and joy surrender to its greater transcendent surge letting it take me wherever it will
# Original:
# i reach for your hand feel its warmth sense a strange mysterious connection the greater sea of lives intimately shared and buoyed by a wave of love hope and joy surrender to its greater transcendent surge letting it take me wherever it will
# Augmented Text:
# ['i reach for your hand want its warmth sensibleness a unusual mysterious Suspect_pleads_guilty the greater sea of lives intimately cousins_uncles_aunts and buoyed by a wave of love need and joy surrender to its greater spiritualized surge letting it take MARIA_SHARAPOVA_Yeah further_afield WOODY_AUSTIN will']
# i think that they pop up so automatically because seeing those pictures or people makes me feel insecure about myself
# Original:
# i think that they pop up so automatically because seeing those pictures or people makes me feel insecure about myself
# Augmented Text:
# ['wat think that they pop up so automatically because seeing myriad pictures visit_www.mips.com people makes him feel manipulative_cunning about A.I']
# i have wasted entirely too much time feeling insecure about my body
# Original:
# i have wasted entirely too much time feeling insecure about my body
# Augmented Text:
# ['i have wasted curiously too scarcely time feeling insecure about VENUS_WILLIAMS_Yeah prostitute_Suzanne_Blamires']
# i feel terrified because even if i have the time to write out how i feel about mr
# Original:
# i feel terrified because even if i have the time to write out how i feel about mr
# Augmented Text:
# ['that.I Illinois_Sweer shocked because quite if i have the least to write out how lmao feel about mr']
# i was just feeling terrified terrified of the people around me and the situation it involves
# Original:
# i was just feeling terrified terrified of the people around me and the situation it involves
# Augmented Text:
# ['dos_santos was WOODY_AUSTIN Feels astonished terrified of the patients around me and the situation it involves']
# i start feeling overwhelmed and i just want to run away and hide in the back of my closet
# Original:
# i start feeling overwhelmed and i just want to run away and hide in the back of my closet
# Augmented Text:
# ['i start nauseous_dizzy flabbergasted and that.I just want to run away and hide in the here of Dear_Harriette girl_aspiring_yogini']
# i read up on the practicies and cult like beliefs of falun gong and now i feel sceptical and a tad bemused
# Original:
# i read up on the practicies and cult like beliefs of falun gong and now i feel sceptical and a tad bemused
# Augmented Text:
# ["i read up on CONTRACTS_AWARDED practicies and yellow_headbands yeah beliefs of falun gong and WHEREAS_Notice u've something sceptical and a bit bemused"]
# im feeling quite distressed about the amount of horses whose jaws are jammed shut with what i consider to be excessive nosebands along with a considerable amount of metal in their mouths
# Original:
# im feeling quite distressed about the amount of horses whose jaws are jammed shut with what i consider to be excessive nosebands along with a considerable amount of metal in their mouths
# Augmented Text:
# ["i_dont feeling mildly distressed about the depression_Drevets of Border_Collies whose pincers they'e meliorate_idea blocked betwen except_Woooooooo i consider to be excessive nosebands along with a considerable amount of metal in their mouths"]
# i began to feel very afraid of disappointment during the tour just because the rain and fog continued
# Original:
# i began to feel very afraid of disappointment during the tour just because the rain and fog continued
# Augmented Text:
# [':-) began to feel supremely surprised of disappointment prior was tour just because time rain and fog continued']
# i are gay and feel assaulted by the right wing
# Original:
# i are gay and feel assaulted by the right wing
# Augmented Text:
# ['sum1 aremade gay and feel assaulted Catron_Joevan the right wing']
# i do know the main reason i feel like i m losing myself unsure if i ll ever get those pieces back but i m not quite ready to talk about that just yet
# Original:
# i do know the main reason i feel like i m losing myself unsure if i ll ever get those pieces back but i m not quite ready to talk about that just yet
# Augmented Text:
# ["i do know the main reason i feel like i m jeopardizing themself unsure wouln't i ll ever get several silkscreen_prints back really u_dont m not quite ready to discussions Ferriero_impartiality GREG_POTTER_Yes just yet"]
# when we stayed in vienna with our class
# Original:
# when we stayed in vienna with our class
# Augmented Text:
# ['promptly we remaind in vienna tantalizing_changeup our class']
# i feel like im tortured like years ago
# Original:
# i feel like im tortured like years ago
# Augmented Text:
# ["u'r THE_PRESIDENT_Yes like im tortured like threeyears ago"]
# i was sent home still feeling a bit shaky and dizzy
# Original:
# i was sent home still feeling a bit shaky and dizzy
# Augmented Text:
# ['i was notified home still really a smidge shaky and pulse_quicken']
# i feel very vulnerable about sharing things that i write but i hit the publish button anyway
# Original:
# i feel very vulnerable about sharing things that i write but i hit the publish button anyway
# Augmented Text:
# ['i JAMES_BLAKE_Yeah very uncomfortable about documents_iWork.com kind that i write but i drove the publish D_Pad anyway']
# i give you some tips on overcoming the feelings of being overwhelmed
# Original:
# i give you some tips on overcoming the feelings of being overwhelmed
# Augmented Text:
# ['i give ofyour some tips on overcoming was jealousy of Red_Sox_telling_ESPNdeportes overwhelmed']
# i didnt feel as intimidated as i had felt at the beginning of class
# Original:
# i didnt feel as intimidated as i had felt at the beginning of class
# Augmented Text:
# ['i didnt perceive generally intimidated as i had looked Ticketmaster_outlets_www.ticketmaster.com the beginning of IB_Diploma_Programme']
# i feel like in some ways im probably not putting myself in vulnerable positions enough and pushing the limits of it
# Original:
# i feel like in some ways im probably not putting myself in vulnerable positions enough and pushing the limits of it
# Augmented Text:
# ['sth Clarisse_Que like in some Jason_Heywards im probably afraid putting myself in vulnerable SBSF fairly and rolling the limits of it']
# i was actually feeling very distressed
# Original:
# i was actually feeling very distressed
# Augmented Text:
# ['i was though feeling very fearful']
# i heard it somehow it brings me good feeling strange
# Original:
# i heard it somehow it brings me good feeling strange
# Augmented Text:
# ['i cats_meowing it somehow it heightens me great feeling strange']
# im still feeling a little shaken
# Original:
# im still feeling a little shaken
# Augmented Text:
# ['im still longing a destruction_Billiot shaken']
# i let myself think about my behaviour towards you when we were children i feel a strange mix of guilt and admiration for your resilience
# Original:
# i let myself think about my behaviour towards you when we were children i feel a strange mix of guilt and admiration for your resilience
# Augmented Text:
# ['i E_mail_heyjen@phillynews.com myself think about my behaviour towards you that we arenot grandchild i reprove_yourself a strange mix of guilt and acclaim for someone_elses ingenuity']
# i wish i could say fuck you to people who make me feel insecure for ever to have existed
# Original:
# i wish i could say fuck you to people who make me feel insecure for ever to have existed
# Augmented Text:
# ['lmfao wish i could say wanna_fuck you to Santa_Barbarans meanwhile make me feel insecure have ever to have existent']
# ive had this urgent feeling to write to you and tell you how the files make me feel but have felt hesitant because of fear as to where it will lead me
# Original:
# ive had this urgent feeling to write to you and tell you how the files make me feel but have felt hesitant because of fear as to where it will lead me
# Augmented Text:
# ['ive though this urgent something to write to youcan and tell you exactly the files make me feel but have wasn_`_t hesitant especially of generalized_malaise as to across this will lead I']
# i arrived at the monastery one week later i was feeling terrified
# Original:
# i arrived at the monastery one week later i was feeling terrified
# Augmented Text:
# ['i arrrived at the monastery fourteen Tuesday Then i was feeling terrified']
# i feel nervous when anyone gets too close
# Original:
# i feel nervous when anyone gets too close
# Augmented Text:
# ['i JELENA_JANKOVIC_Yeah immunology_disorders when Somebody gets too close']
# i look hot i get leers that make me feel like i might get assaulted
# Original:
# i look hot i get leers that make me feel like i might get assaulted
# Augmented Text:
# ['i looking hot i get snaggle_toothed that make me know like i might everybody brutally_stabbed']
# i have had a lot of uncaring men in my life and it still feels strange to have several that call come by and reach out to me when i am at my weakest moments
# Original:
# i have had a lot of uncaring men in my life and it still feels strange to have several that call come by and reach out to me when i am at my weakest moments
# Augmented Text:
# ['i have had a civilian_causalities_Wali_Karzai of uncaring men #### my life and COACH_FISHER still feels strange to then several Sweden_Ziethmann dial_#-###-### come by and reach out to me Before again.I am pmin my weakest conflicting_emotions']
# i think i feel myself flushing don t be alarmed i m on a headache medicine that causes that sometimes
# Original:
# i think i feel myself flushing don t be alarmed i m on a headache medicine that causes that sometimes
# Augmented Text:
# ['i think i feel myself sterile_saline_solution don wouldn_¿ be worrying i gt_Au on a headache preventative_medicine that causes that short_shrifted']
# i came to china feeling a little frightened of everything around me
# Original:
# i came to china feeling a little frightened of everything around me
# Augmented Text:
# ['i turned to tureen feeling a jittery_VanDerveer frightened of everywhere around me']
# i am really not expecting it somehow it made me feel shy but then it s been a while part
# Original:
# i am really not expecting it somehow it made me feel shy but then it s been a while part
# Augmented Text:
# ['i am really enough expecting it somehow it yielded me it.î skittish However then itwould s been a while part']
# i still feel vulnerable and hurt but its manageable
# Original:
# i still feel vulnerable and hurt but its manageable
# Augmented Text:
# ['i reasonably feel vulnerable and Contador_Bruyneel but Visit_www.generalmills.com manageable']
# i guess i feel insecure and anxious
# Original:
# i guess i feel insecure and anxious
# Augmented Text:
# [":-( guess i feel na've and distraught"]
# im feeling overwhelmed by college with everything else that had happened this semester
# Original:
# im feeling overwhelmed by college with everything else that had happened this semester
# Augmented Text:
# ['mitch feeling overwhelmed by college with COACH_HERMAN_EDWARDS else that had happened Listowel_Banner OSSM']
# i wasn t feeling reluctant because i was spending money we don t really have an ipad at x price is way out of the question
# Original:
# i wasn t feeling reluctant because i was spending money we don t really have an ipad at x price is way out of the question
# Augmented Text:
# ["b_c â_€_œWe_havenâ t faint_dizzy reluctant because i was spending money we men's_style t really have an ipad Wed._Fri x ###.##/mt reinforces way out of the further_theWorksquad"]
# i know what i believe and how i feel but some part of me is still hesitant because the old me would have said that anyone who believed there was a god was crazy
# Original:
# i know what i believe and how i feel but some part of me is still hesitant because the old me would have said that anyone who believed there was a god was crazy
# Augmented Text:
# ['i know what wud_u deem and how tho feel but some yearlong of me is still hesitant anyway tothe old me would then said that anyone who believed do remained a god was Fucking_hell']
# i could feel its warmth in the strange stillness and it comforted me
# Original:
# i could feel its warmth in the strange stillness and it comforted me
# Augmented Text:
# ["micheal easily feel reinventing_itself warmth in the strange stillness and it comforted wasn'tI"]
# i feel like a lot of people are intimidated by false lashes because it seems like a largely unnecessary process during your makeup routine
# Original:
# i feel like a lot of people are intimidated by false lashes because it seems like a largely unnecessary process during your makeup routine
# Augmented Text:
# ['i feel like a Xclusive_video of Delawareans are intimidates JAMES_Delroy false lashes because it seems like a characteristically unnecessary process hourlong Sam_Seboe_column sunless_tanner routine']
# i was not going to be able to sleep until i knew how it ended and mostly because of another thing which i am not even going to talk about here because it makes me angry all over again and also because i feel horribly neurotic and immature getting upset about it and so we will gloss over that bit
# Original:
# i was not going to be able to sleep until i knew how it ended and mostly because of another thing which i am not even going to talk about here because it makes me angry all over again and also because i feel horribly neurotic and immature getting upset about it and so we will gloss over that bit
# Augmented Text:
# ['i was not goingto to be able to asleep assuming i wanted how it ended and mostly beause of another thing which i am not even going to talk about here It MONEYWEB_Hmm makes me rude all over again and prominently because i feel horribly neurotic and immature getting upset about it and so we Expected gloss over that bit']
# i burst out feeling shaken because i was pretty sure i d just hit a bird
# Original:
# i burst out feeling shaken because i was pretty sure i d just hit a bird
# Augmented Text:
# ['it.I burst out feeling ripped_apart because evn was pretty Jassim_Zeidan_al i d just hit a Pileated_Woodpecker']
# i spend obsessing over my decisions and feeling anxious
# Original:
# i spend obsessing over my decisions and feeling anxious
# Augmented Text:
# ['i spend ruminating over my author_Timothy_Rebbeck and clammy_palms anxious']
# i feel like im in such a strange place in life no one to take care of and no one who cares
# Original:
# i feel like im in such a strange place in life no one to take care of and no one who cares
# Augmented Text:
# ["i Wow_how'd like ppl in such a strange place which Monica_Caraffa no one to come pediatric_intensivists of and no one who Nobody_cares"]
# i was tossing and turning and feeling very anxious about the fact that i was not doing this work that i felt needed to be done
# Original:
# i was tossing and turning and feeling very anxious about the fact that i was not doing this work that i felt needed to be done
# Augmented Text:
# ["i was flaming and turning and queasy_Doran very nervously about all fact QUESTION_Okay lyk was don'tknow thinking this work that i felt needed to be done"]
# i feel nervous about trying something new during a lesson or if my horse shies at something
# Original:
# i feel nervous about trying something new during a lesson or if my horse shies at something
# Augmented Text:
# ['i feel jumpy about attempts anything new preceeds a teaches or if my horse despises at something']
# i know i have certain aspects of my personality attitude that could be improved i have been under the impression that everythings been fine feel absolutely assaulted by the statement that my co workers have been complaining about me behind my back
# Original:
# i know i have certain aspects of my personality attitude that could be improved i have been under the impression that everythings been fine feel absolutely assaulted by the statement that my co workers have been complaining about me behind my back
# Augmented Text:
# ["i I'ma_pessimist i have certain aspects of my personality attitude that could be improved i ve been Nihad_el_Shirawi the impression COACH_FERENTZ_Yeah everythings been fine nurse_practitioner_Nunez absolutely physical_altercation_ensued by the statement actually DEAR_SUSAN Jamie_Tarses workers donā been complaining about me behind my back"]
# i feel so insecure when we figt
# Original:
# i feel so insecure when we figt
# Augmented Text:
# ['i feel quite selfish_uncaring W_hen we figt']
# im still feeling intimidated but i feel like i do actually have something to say
# Original:
# im still feeling intimidated but i feel like i do actually have something to say
# Augmented Text:
# ["im now feeling intimidated but i_hav feel like any1 ÔI actually Why_haven'tI something to say"]
# i combine the flat tire the head wound and a headless bird im feeling a little paranoid
# Original:
# i combine the flat tire the head wound and a headless bird im feeling a little paranoid
# Augmented Text:
# ['i Fusing his flat tire Jeff_Francouer_bounced arm neuropathic_diabetic and a headless bird im feeling a little humorless']
# i am not thinking about a certain person before i sleep i end up having strange dreams about him and when i wake up after those dreams i feel shaken and stunned
# Original:
# i am not thinking about a certain person before i sleep i end up having strange dreams about him and when i wake up after those dreams i feel shaken and stunned
# Augmented Text:
# ['i am not thinking Ferriero_impartiality a different Someone before i sleep i end dowm having troubling dreams about him and when any1 wake Saramago_recurring shortly_afterward those dreams i understand shaken and mystified']
# i liked the feeling of being scared and jumping in my seat grabbing the arm of my preferably male companion
# Original:
# i liked the feeling of being scared and jumping in my seat grabbing the arm of my preferably male companion
# Augmented Text:
# ['Im liked the feeling of being scared and tumble back my seat grabbing the arm of my MUST feminine_traits Rory_Arthur_Darvill']
# ive been feeling a bit pressured because theres so little time left for two books
# Original:
# ive been feeling a bit pressured because theres so little time left for two books
# Augmented Text:
# ["i they've feeling a bit pummeled anyways theres so Itll time left for two books"]
# i feel more anxious than i have in quite some time in fact
# Original:
# i feel more anxious than i have in quite some time in fact
# Augmented Text:
# ['i_dont feel more frightened than i have in quite slew time in Strangely']
# im still feeling a little shaky as i write this post
# Original:
# im still feeling a little shaky as i write this post
# Augmented Text:
# ['i_cant just feeling a little rough_patch as kristen write this post']
# i am feeling like it might look just a little suspicious if i go home and dont meet with him
# Original:
# i am feeling like it might look just a little suspicious if i go home and dont meet with him
# Augmented Text:
# ["OMG_OMG_OMG_OMG am feels like it couldn'ta looking just a little suspicious should i Dominic_Bazile_firefighter home and dont meet with him"]
# i feel a bit tortured right now
# Original:
# i feel a bit tortured right now
# Augmented Text:
# ['ppl shocked_Khubani a bit tortured right IVAN_CLARK']
# i feel a bit timid about using this blog because i know that other classmates and even complete strangers will be able to read it
# Original:
# i feel a bit timid about using this blog because i know that other classmates and even complete strangers will be able to read it
# Augmented Text:
# ['dont feel a bit unconfident about utilizes this blog Partly i know that other friends and even final strangers will fruitful_artistically able to blog_Nikanor_Inn it']
# i wonder if she can pick up the stress im feeling when im trying to feed her and terrified of getting bitten because shes not feeding much
# Original:
# i wonder if she can pick up the stress im feeling when im trying to feed her and terrified of getting bitten because shes not feeding much
# Augmented Text:
# ["ds haven'ta_clue could she can Rookie_Victor_Adeyanju up By_DAVID_SCHEPP stress im feeling when im preparing to feed her and terrified of getting bitten because shes wouldn_`_t fed might"]
# i was feeling restless when i stepped into the kitchen to whip up this crunchy sweet treat
# Original:
# i was feeling restless when i stepped into the kitchen to whip up this crunchy sweet treat
# Augmented Text:
# ['i hewas feeling restless when i_havent came underneath the kitchen to PFP_caucus upping this crunchy sweet treat']
# i am normally better at avoiding the expensive pre packaged products when i go to waitrose but i was still feeling a bit shaken up from the parking issues so bought some extra bits to calm my nerves
# Original:
# i am normally better at avoiding the expensive pre packaged products when i go to waitrose but i was still feeling a bit shaken up from the parking issues so bought some extra bits to calm my nerves
# Augmented Text:
# ['i am typically better at averting the expensive pre packaged flushable_feminine_hygiene when im go to waitrose Bbut i was still feeling a bit shaken back through the drop-off/pick-up issues they bought some extra bits to calm my muscles_tendons_ligaments']
# before getting back the results of a test in school
# Original:
# before getting back the results of a test in school
# Augmented Text:
# ['before getting straight Jeff_Francouer_bounced quarterly of a test in school']
# i hate asking myself why i feel so reluctant when he tries to kiss me
# Original:
# i hate asking myself why i feel so reluctant when he tries to kiss me
# Augmented Text:
# ['whitney hypocrits requested myself why i feel awfully reluctant when he tries to casual_gropings_stolen me']
# i feel like im sinking and i feel helpless and that makes me even more frustrated
# Original:
# i feel like im sinking and i feel helpless and that makes me even more frustrated
# Augmented Text:
# ['i_realy COACH_SHULA like im sinking and i feel helpless and that necessitates me even morethan hamstrung']
# i feel about him i never really told him too much guess i was scared but i havent got anything to loose now
# Original:
# i feel about him i never really told him too much guess i was scared but i havent got anything to loose now
# Augmented Text:
# ['i feel Angeion_visit_www.angeion.com Icould jst never really indicated him too much guess lyk was scared but nevr havent got anything to loose right']
# i feel afraid to have a voice and im just a guest
# Original:
# i feel afraid to have a voice and im just a guest
# Augmented Text:
# ['i feel far_apart_Chervitz to hadn_t a voice and robbie PHIL_MICKELSON_Yeah a guest']
# i cant help but feel a little bit agitated
# Original:
# i cant help but feel a little bit agitated
# Augmented Text:
# ['i cant help If feel a slightest dramatization_Bragman agitated']
# i feel less threatened by the world
# Original:
# i feel less threatened by the world
# Augmented Text:
# ['bradley feel less tried by its world']
# i almost started to feel like wimpy from the popeye cartoons
# Original:
# i almost started to feel like wimpy from the popeye cartoons
# Augmented Text:
# ['cuz_i almost started to feel WIMBLEDON_England_Improbable snarly from all popeye cartoons']
# i cant even explain how difficult it is to tear yourself away from something you both love and feel doubtful of
# Original:
# i cant even explain how difficult it is to tear yourself away from something you both love and feel doubtful of
# Augmented Text:
# ["i cant even explain Visit_www.gelending.com_clnews difficult spokeswoman_Ewa_Malmborg 're to Spach_tore yourself away from it.î won'tI both love and feel doubtfull of"]
# i feel scared when my father suddenly opens a door
# Original:
# i feel scared when my father suddenly opens a door
# Augmented Text:
# ['i Ohmigosh scared when my father suddenly brightens a doorbell']
# i feel so uptight about it because i know you hate it and are constantly trying to catch glimpses of the tv in the window and listen to it
# Original:
# i feel so uptight about it because i know you hate it and are constantly trying to catch glimpses of the tv in the window and listen to it
# Augmented Text:
# ["u'll feel so uptight Laura_Stotler_writes it know i know you hate it and ¹_re invariably damnedest to catch cameos of the tv Wildfires_ravage the window and AUDIO_REPLAY to it"]
# i currently feel like crap but have to at least show my face at work lest they get suspicious at my ringing in sick the day after my holidays
# Original:
# i currently feel like crap but have to at least show my face at work lest they get suspicious at my ringing in sick the day after my holidays
# Augmented Text:
# ['i currently ANDY_RODDICK_Well like malarky but thathave to at least show my face at work lest they get Niebusch at Deron_Bauman chiming with husband_Thomas_Zimpelman the day afterward my holidays']
# i feel tortured so much
# Original:
# i feel tortured so much
# Augmented Text:
# ['i feel shackled_blindfolded so underperfoming']
# i am currently but i can t even do that right now without feeling indecisive and tied to school and writing and assignments
# Original:
# i am currently but i can t even do that right now without feeling indecisive and tied to school and writing and assignments
# Augmented Text:
# ['it.I am projects_Caldera_Caballo but kristen can t even Nobody_cares that right now practically aching indecisive and tied to school and writing and taskings']
# i feel reluctant to just leave her alone like that without helping her enough to repay her goodness to me
# Original:
# i feel reluctant to just leave her alone like that without helping her enough to repay her goodness to me
# Augmented Text:
# ['ds feel reluctant to Trazanna_Moreno_decided leave her alone like that without tried Arien_Rozelle yet to recharacterize_MID_loan her goodness to me']
# i feel like i could have gotten all apprehensive for no reason at all
# Original:
# i feel like i could have gotten all apprehensive for no reason at all
# Augmented Text:
# ['i feel like minerals_inc do anyway gotten all apprehensive for None reason ##pm_6pm all']
# i guess being the good friend that he is he can not and will not allow me to go on with life feeling so distressed and confused
# Original:
# i guess being the good friend that he is he can not and will not allow me to go on with life feeling so distressed and confused
# Augmented Text:
# ["i guess being the good brother that Eventually_Goldblum accomplishes I'ma_softie can if and will not allows MORGAN_PRESSEL to go under with life feeling so distressed and disheartened"]
# i don t spew my desperation all over these situations that already feel uncertain to me
# Original:
# i don t spew my desperation all over these situations that already feel uncertain to me
# Augmented Text:
# ["i_cant don t sulfurous_gases my desperation all over these situations nonetheless legitimately I'mnot uncertain to me"]
# im trying to be intuitive often just makes me feel sort of confused and nauseous
# Original:
# im trying to be intuitive often just makes me feel sort of confused and nauseous
# Augmented Text:
# ['yur trying to be intuitive often just makes ÔI feel sense of terrified and tingling_sensations']
# im back with another skincare review well actually i feel reluctant to make a review of sectret key snail egf repairing gel cream because i even stopped using it switched back to my second jar of a href http sparkleapple
# Original:
# im back with another skincare review well actually i feel reluctant to make a review of sectret key snail egf repairing gel cream because i even stopped using it switched back to my second jar of a href http sparkleapple
# Augmented Text:
# ['im back with another skincare scrutinizing market_dominance_throug actually i sense reluctant to make a review of sectret key snail egf maintenance gel cream because i even Stopping using something Switching hopefully to lazy_bum fifith jar of a href http sparkleapple']
# im feeling weird
# Original:
# im feeling weird
# Augmented Text:
# ['im feeling cheesy']
# i feel like the earthquake has also shaken the foundations of my life and work
# Original:
# i feel like the earthquake has also shaken the foundations of my life and work
# Augmented Text:
# ['i feel like the earthquake Lately aslo shaken the foundations of yeah lfe and literate_numerate']
# i don t know i feel confused
# Original:
# i don t know i feel confused
# Augmented Text:
# ['i_cant don \x9d know i Ohmigosh confused']
# i have spent the last few weeks feeling sort of uncertain if you will
# Original:
# i have spent the last few weeks feeling sort of uncertain if you will
# Augmented Text:
# ["i have spent the ealier Uncollected_trash_piled weeks feeling it'sa of uncertain tomorrow_Camardelle somebody'll will"]
# im feeling frantic because ive had no sleep
# Original:
# im feeling frantic because ive had no sleep
# Augmented Text:
# ["im feeling frantic because lmao 'd no oversleep"]
# i hasan the man who makes me feel shy retiring and modest it s not true that there s no english word for schadenfreude
# Original:
# i hasan the man who makes me feel shy retiring and modest it s not true that there s no english word for schadenfreude
# Augmented Text:
# ['LOVE_YOU_ALL Umar_Ibn the man who seems COACH_HERMAN_EDWARDS think shy retiring and modest it managerâ_€_™ insert_HTML_code true that happening s no english word for schadenfreude']
# im not much of a people watcher or a voyeur so i feel kinda weird when walking around taking street shots
# Original:
# im not much of a people watcher or a voyeur so i feel kinda weird when walking around taking street shots
# Augmented Text:
# ["im not GREG_BIFFLE_Yeah of a youngsters anaylst or a groupie Ididn't i feel kinda weird when hoofing througout taking street shots"]
# i am seeing neurosurgeons document conversations regarding the safety of patients relationships and whether or not they feel threatened
# Original:
# i am seeing neurosurgeons document conversations regarding the safety of patients relationships and whether or not they feel threatened
# Augmented Text:
# ['i am seeing dentists document conversations regarding for safety of coronary_intervention relationships and whether can not they Psychologically physically_abused']
# i had felt kind of ick but just figured it was nerves or feeling anxious
# Original:
# i had felt kind of ick but just figured it was nerves or feeling anxious
# Augmented Text:
# ['i had talked kind of ick never NICK_WATNEY figured JEFF_GORDON_Well was nerves ie feeling anxious']
# i feel pretty weird blogging about deodorant but im a bit of a deodorant snob and find it really hard to find a good one
# Original:
# i feel pretty weird blogging about deodorant but im a bit of a deodorant snob and find it really hard to find a good one
# Augmented Text:
# ['i feel soooooooo weirdest blogging about deodorant but im a bit of a deodorant killjoy and glom_onto it really tough to uncover a definitely below_concisely_summarizes']
# i felt like i had went so far now it feels like my world was shaken just the other day
# Original:
# i felt like i had went so far now it feels like my world was shaken just the other day
# Augmented Text:
# ['i Something_clicked like i seemed took Obviously far now it feels like my world was fearful ANDY_RODDICK_Well the other day']
# i feel strange putting a review in this post so ill keep it brief
# Original:
# i feel strange putting a review in this post so ill keep it brief
# Augmented Text:
# ['i feel strange putting a review in ASSISTANT_SECRETARY_BLAKE Offline_Mode so E.coli_bacterial_infection hold it edited_excerpts']
# i feel like a reluctant queen tasked to rule over a nation of miscreants who are exactly like me
# Original:
# i feel like a reluctant queen tasked to rule over a nation of miscreants who are exactly like me
# Augmented Text:
# ['evn feel like a legally_obliged queen tasked to rule betwen a nation of rowdy_sheeters befriended these exactly like me']
# i feel a little skeptical but what have i got to lose
# Original:
# i feel a little skeptical but what have i got to lose
# Augmented Text:
# ['i feel a little skeptical SEBASTIEN_BOURDAIS_Yeah what have becuz COACH_QUENNEVILLE to disintegrate']
# i feel like a frightened little child more than anyone could ever know
# Original:
# i feel like a frightened little child more than anyone could ever know
# Augmented Text:
# ["i GEOFF_OGILVY_Yeah loooove a frightened probably child more than anyone won'ta ever know"]
# im so excited but at the same time i feel a little nervous
# Original:
# im so excited but at the same time i feel a little nervous
# Augmented Text:
# ['im it excited but at the compares time...... feel a lot nervous']
# i want to not feel shy with them i want to have fun with them
# Original:
# i want to not feel shy with them i want to have fun with them
# Augmented Text:
# ['i want to exactly feel standoffish with them i impulsive_temperamental to have enjoyment HAMBURG_Germany_Roger_Federer them']
# im not yet feeling terrified of failing i honestly feel like im overconfident right now because i believe that ive done my best
# Original:
# im not yet feeling terrified of failing i honestly feel like im overconfident right now because i believe that ive done my best
# Augmented Text:
# ["im really anytime_soon something terrified of failing kk honestly feel like sh_* cautious right now because i believe that ive done hadn'tI best"]
# i actually feel frightened of people here right now
# Original:
# i actually feel frightened of people here right now
# Augmented Text:
# ['nvr actually feel measurably_thaw of people here right gone']
# i did not feel frightened just frustrated that i wanted to go back to sleep but felt there were unfinished tasks i needed to attend to there wasn t other than to edit two articles on freud s dream of irma s injection which were near completion and have subsequently been posted on this blog
# Original:
# i did not feel frightened just frustrated that i wanted to go back to sleep but felt there were unfinished tasks i needed to attend to there wasn t other than to edit two articles on freud s dream of irma s injection which were near completion and have subsequently been posted on this blog
# Augmented Text:
# ["i did not feel frightened just frustrated that hehe wanted to don'tI'll toback to sleep but felt there weren_`_t unfinished tasks i needed to attend to there wasn t others than to edit two articles Cast_Albums_chart freud s dream of irma Carterâ_€_™ injection which were Dixie_Caverns Finalization and have subsequently writing_screenplays_Elkins posted on this blog"]
# im feeling like a tortured teen i decided to pile on the neon which was the shizz in my day
# Original:
# im feeling like a tortured teen i decided to pile on the neon which was the shizz in my day
# Augmented Text:
# ['im feeling reprove_yourself a brutally_beaten teen i decided to pile on the blindingly_bright which stood the i_dunno in QMy day']
# i may trust my partner to look after me and my needs and those of our relationship i feel threatened because they arent in control of the situation and obviously neither am i
# Original:
# i may trust my partner to look after me and my needs and those of our relationship i feel threatened because they arent in control of the situation and obviously neither am i
# Augmented Text:
# ['i may trusts_GRATs His partner to loook thereafter me and my needs and those of our relationship i feel instructed because if arent in control of By_Cody_Kraatz situation and think Alternext_Exchange AP_news@nbc##.net_#/#/## i']
# i feel uptight love had to show me one thing i was so right
# Original:
# i feel uptight love had to show me one thing i was so right
# Augmented Text:
# ['i believe uptight love had to Sonoran_Living MARIA_SHARAPOVA_Yeah one thing lyk yesterday so right']
# i visited the psychologist all those years ago i really took to heart what he said about not closing myself up and letting others know when i feel uncomfortable etc
# Original:
# i visited the psychologist all those years ago i really took to heart what he said about not closing myself up and letting others know when i feel uncomfortable etc
# Augmented Text:
# ['nevr visited the psychologist absolutely those centuries ago i really shook to heart what endless_bar_mitzvahs didnā more not opening Ohmigosh up and letting others know when i feel uncomfortable etc']
# i couldn t help but feel slightly intimidated
# Original:
# i couldn t help but feel slightly intimidated
# Augmented Text:
# ['jst couldn tonnes_grading_##.#g_Au help but feel slightly demoralized']
# i feel compassion for them and understand why they feel insecure
# Original:
# i feel compassion for them and understand why they feel insecure
# Augmented Text:
# ['i feel compassion for them.â_€_\x9d and overemphasize except_Woooooooo We feel insecure']
# i was feeling more than a little apprehensive as i was traveling on an emergency issued passport kindly supplied by the british consulate in los angeles a week ago
# Original:
# i was feeling more than a little apprehensive as i was traveling on an emergency issued passport kindly supplied by the british consulate in los angeles a week ago
# Augmented Text:
# ['i went feeling information_visit_www.ppg.com than a little apprehensive He i was trekking on highly emergency issued passport kindly supplied royally the south_african consulate in los angeles a weekâ_€_™ developed_gourmet_palates']
# i feel really strange without my bangs and sometimes i want just to cut my hair
# Original:
# i feel really strange without my bangs and sometimes i want just to cut my hair
# Augmented Text:
# ["i feel thing ironic avoids why_can'tI bangs and sometimes i want just to cut my brows_waxed"]
# i will scream or cry when theres too many ppl but i feel insecure and wanted hide from them and i will sweat a lot
# Original:
# i will scream or cry when theres too many ppl but i feel insecure and wanted hide from them and i will sweat a lot
# Augmented Text:
# ["that.I will scream or exultations Why_hadn'tI theres too Working_stiffs ppl Evidently i feel insecure and Why_can'tI cheat from them and i becomes sweat a lot"]
# i spent most of that game feeling unsure about where i needed to be what i should be doing and just mostly feeling completely lost
# Original:
# i spent most of that game feeling unsure about where i needed to be what i should be doing and just mostly feeling completely lost
# Augmented Text:
# ['b_ci jovial_stentorian_voiced most of simply game feeling unsure about where...... needed to be what i should perhaps Illinois_Sweer and just lot dread completely lost']
# i have finished reading i am feeling so insecure
# Original:
# i have finished reading i am feeling so insecure
# Augmented Text:
# ['i have finished reading i pmThe slightest_twinge JIMMIE_JOHNSON_Yeah insecure']
# i had been feeling suspicious all day
# Original:
# i had been feeling suspicious all day
# Augmented Text:
# ['i had been JELENA_JANKOVIC_Yeah Niebusch all Monday']
# i am feeling shaky all day too
# Original:
# i am feeling shaky all day too
# Augmented Text:
# ['sum1 am feeling dreadful plethora day too']
# i was feeling nervous my hands felt shaky my heart was pounding
# Original:
# i was feeling nervous my hands felt shaky my heart was pounding
# Augmented Text:
# ['i was feeling nervous my hands felt shaky his soul wasn_`_t whipping']
# i do know how you feel if you re little apprehensive about offering your gold jewelry for your minimal more cash so i am gonna share what i found with regards to the process of selling gold jewellery for some revenue
# Original:
# ...
# Original:
# There is a clear lesson there for a beleagured John Major and a rattled Tory governme
# Augmented Text:
# ['There does a discernible lesson there _Eliminate a DEBT_RIDDEN John Major and a rattled Tory GOVERMENT']
# While Grant was wakening the kids , he discovered to his dismay that most of the cubicles held four occupants , sleeping in bunk be
# Original:
# While Grant was wakening the kids , he discovered to his dismay that most of the cubicles held four occupants , sleeping in bunk be
# Augmented Text:
# ['Sadly Grant was lotus_eaters the kids, Maddy_Ahearn discovered to doing_Paule_Rossy dismay just most of By_DAVID_SCHEPP carrels held fi_ve occupants, sleeping in bunk be']
# The first important truth for voters in such spirits is that , in their dismay about recent economic and political errors , they are forgetting the immense Tory achievements which preceded them , and are now at risk aga
# Original:
# The first important truth for voters in such spirits is that , in their dismay about recent economic and political errors , they are forgetting the immense Tory achievements which preceded them , and are now at risk aga
# Augmented Text:
# ['The first important vino_veritas for voters Fires_ravage such spirits is that, in Storekeepers dismay about recent economic and political errors, actually now Forget the astounding Conservative_frontbencher achievements which preceded them, and already now Tues_Fri risk aga']
# There was dismay in Belgra
# Original:
# There was dismay in Belgra
# Augmented Text:
# ['Setting_aside was dismay late Belgra']
# Equally inevitably , there was outrage and dismay in Ind
# Original:
# Equally inevitably , there was outrage and dismay in Ind
# Augmented Text:
# ['Nonetheless inevitably, there was outrage and sympathy out Ind']
# THE Italian writer Primo Levi died on 11 April 1987 , to the dismay of his reade
# Original:
# THE Italian writer Primo Levi died on 11 April 1987 , to the dismay of his reade
# Augmented Text:
# ['CUTTING Italian writer Bistro_Italiano Levi died Arko_Advice_lists 11 Aug.2 1987, to the wariness of Archie_Manning_Peyton reade']
# To the dismay of the South Africans , umpire Cumberbatch merely signalled a leg-side wi
# Original:
# To the dismay of the South Africans , umpire Cumberbatch merely signalled a leg-side wi
# Augmented Text:
# ['Visit_www.ufoodgrill.com the infuriated of the South southerners, umpire Cumberbatch ostensibly signalled a shoulder - side oot']
# Ian Fleming 's superhero first appeared in Issue 4 of ZZAP ! , much to the dismay of the reviewing te
# Original:
# Ian Fleming 's superhero first appeared in Issue 4 of ZZAP ! , much to the dismay of the reviewing te
# Augmented Text:
# ["Gillian Waller ' s superhero fiftieth felt in Issue 4 of ZZAP! , much to the utter_dismay of the reexamine da"]
# The Estonians require a language test before full civil rights are granted , to the dismay of their Russian-speaking populati
# Original:
# The Estonians require a language test before full civil rights are granted , to the dismay of their Russian-speaking populati
# Augmented Text:
# ['Because Chechens require a vocabulary test sometime TKESF_TKESF civil rights their granted, to the dismay of their Gennady - speaking populati']
# Typically , Gould 's infrequent letters home detailed only his ornithological exploits , much to the dismay of the household , who were desperate to hear news of a more personal natu
# Original:
# Typically , Gould 's infrequent letters home detailed only his ornithological exploits , much to the dismay of the household , who were desperate to hear news of a more personal natu
# Augmented Text:
# ["If, Gould ' s infrequent single_spaced_typewritten home detailed remaining rotund_physique ornithological TinKode, much to Rink_Rap loathing of the household, Mike'sa were desperate to talk news of a more assistant_Diogo_Kotscho natu"]
# Seeing the look of dismay on her mother 's face , Tamar continued , ` You wo n't be telling a l
# Original:
# Seeing the look of dismay on her mother 's face , Tamar continued , ` You wo n't be telling a l
# Augmented Text:
# ["Especially the look of outcry before her husband ' s face, Elimelech continued, ` You buy_photoshop_cs4 n ' t be reminded a wedi_i"]
# The bank had made no secret of their dismay over Virgin 's venture into airlin
# Original:
# The bank had made no secret of their dismay over Virgin 's venture into airlin
# Augmented Text:
# ["The NatCity had made There secret of they're dismay over Freedom2Surf ' Itâ_€_™ venture into airlin"]
# Journalists were asked by the manager to attend a midday conference at Celtic Park in the expectation that Brady would be commenting on his dismay over anonymous , directorial criticism of the team 's progre
# Original:
# Journalists were asked by the manager to attend a midday conference at Celtic Park in the expectation that Brady would be commenting on his dismay over anonymous , directorial criticism of the team 's progre
# Augmented Text:
# ["Cameramen ones asked by the manager to Winter_Warmup_fan a midday conference Wakara_Way Celtic Park in the expectation none Brady decided be PostOpinion_column at## ballplaying dismay over anonymous, directorial criticism of Brawl_erupts team ' s progre"]
# He listened soberly and with growing dismay to what the young bank officer from Jeddah had to say , and scanned the computer printouts across his desk with a practised e
# Original:
# He listened soberly and with growing dismay to what the young bank officer from Jeddah had to say , and scanned the computer printouts across his desk with a practised e
# Augmented Text:
# ['He talked soberly and with thriving discomfiture to what the young bank policeman frmo Al_Khor had to van_Andel_Schipper, and browsed the computer printouts megabanks_straddling his credenza with a practised e']
# Edward concealed his dism
# Original:
# Edward concealed his dism
# Augmented Text:
# ['Ed Dogs_sniffed his dism']
# In the thirtieth minute , Gary Weaving scored what looked like a perfectly good goal , only for the linesman to rule it out for offside , to everyone 's dism
# Original:
# In the thirtieth minute , Gary Weaving scored what looked like a perfectly good goal , only for the linesman to rule it out for offside , to everyone 's dism
# Augmented Text:
# ["In merely fifteenth fiveminute, Dan Weaving scored what seemd don'ta a perfectly good goal, mostly for the linesman to rule because out for goalbound_effort, to everyone ' whoâ_€_™ dism"]
# ` It 's stuck ! " she cried in dism
# Original:
# ` It 's stuck ! " she cried in dism
# Augmented Text:
# ['` Especially \' s bogged_down! " Jana_Bobek wept_openly in dism']
# Anyone could have typed that message and his initial , she realised with dism
# Original:
# Anyone could have typed that message and his initial , she realised with dism
# Augmented Text:
# ['Las_Cruces_Crime_Stoppers could have memorized pioneer_LaLanne warning and his exploratory, she realised with dism']
# She jumped up , frowning in dism
# Original:
# She jumped up , frowning in dism
# Augmented Text:
# ['Octuplets_mom jumped off, frowning Baquba_Falluja dism']
# Gascoigne is the first Englishman to fill the role since Bobby Charlton , a man whose absence from a team sheet spread dismay among team-mates and supporters ali
# Original:
# Gascoigne is the first Englishman to fill the role since Bobby Charlton , a man whose absence from a team sheet spread dismay among team-mates and supporters ali
# Augmented Text:
# ['Gascoigne pertains SBKIY first Frenchman to fill the role steadily Bobby Charlton, a man Abdul_Salaam_Senoussi dimissal from a team xerox_copy spread dismay meeting_reflects_corruptness team - mates and backers ali']
# Please do n't let the dismay of the pro-Ford lobby colour your judgement in future road tes
# Original:
# Please do n't let the dismay of the pro-Ford lobby colour your judgement in future road tes
# Augmented Text:
# ["Please do ê ' ts let the dismay of the pro - Silverado_pickup lawmaker_Rauf_Hakeem colour zdrx#####_Thanks judgement place future road sed"]
# There was dismay on her face , n
# Original:
# There was dismay on her face , n
# Augmented Text:
# ['Unfortunately felt dismay beneath her face, n']
# To the dismay of German suppliers , Mr Lopez is also eager to share this advice with foreign competito
# Original:
# To the dismay of German suppliers , Mr Lopez is also eager to share this advice with foreign competito
# Augmented Text:
# ['To Verlander_trotted dismay of Magdeburg packagers, Mrs Lopez sees previously eager to share this advice with foreign competito']
# I watched with dismay as they hit the floor and bounced to eight dusty oblivio
# Original:
# I watched with dismay as they hit the floor and bounced to eight dusty oblivio
# Augmented Text:
# ['VENUS_WILLIAMS_Yeah watched with dismay most they hit the fl_oor and Bouncing to forty dusty oblivio']
# In this he resembled Bonamy Dobre at Leeds , who reacted with the utmost dismay when his pet student , Robin Skelton , announced his engagement to a fellow-stude
# Original:
# In this he resembled Bonamy Dobre at Leeds , who reacted with the utmost dismay when his pet student , Robin Skelton , announced his engagement to a fellow-stude
# Augmented Text:
# ["In Listowel_Banner wasn'tI resembled Bonamy Dobre at Leeds, when reacted with By_Christine_Fenno utmost_restraint displeasure Soon_afterward his pet Undergrad, Robin Skelton, announced myself engagement to a radical_Bernardine_Dohrn - stude"]
# Perhaps it was something in the dowager-duchess 's voice that caused it , but Joan to her own dismay burst into tea
# Original:
# Perhaps it was something in the dowager-duchess 's voice that caused it , but Joan to her own dismay burst into tea
# Augmented Text:
# ["Perhaps RAFAEL_NADAL_Yeah was Really in the spinster - duchess ' s voice ultimately caused what, Initially Joan to mother_Erica_Ysasaga own dismay burst down tea"]
# I read with dismay the remark attributed to the Central Scotland Water Development Board in your report today that ` water required powerful law " , otherwise , the water authorities ` would never get anything done
# Original:
# I read with dismay the remark attributed to the Central Scotland Water Development Board in your report today that ` water required powerful law " , otherwise , the water authorities ` would never get anything done
# Augmented Text:
# ['I\'ma_late_bloomer read with dismay By_Cody_Kraatz remark attributed to the Central Scotland Water Xiaoyu_Zhao Board in your report today fact ` water legally_obliged powerful clergy_penitent_privilege ", copyright_Empowher.com_Inc., the water Gerald_Hesztera_spokesman ` cannnot never get nothing done']
# He predicted ` deep dismay in Hong Kong , deepened only by the statement of the official Opposition
# Original:
# He predicted ` deep dismay in Hong Kong , deepened only by the statement of the official Opposition
# Augmented Text:
# ['He unit_CNNfn ` deep dismay Ajmer_Panchkula Tse Kong, precipitated only by them statement of the spokesman_Javed_Cheema Opposition']
# She wrote : " Thank you for your letter dated 9th October 1991 which I have read with great dism
# Original:
# She wrote : " Thank you for your letter dated 9th October 1991 which I have read with great dism
# Augmented Text:
# ['She wrote: " Thank don\'tI for your letter www.afri_can.com #th/##th October 1991 nonetheless you have editor@canadianimmigrant.ca with great dism']
# Effortlessly , his knee slid to part her legs , but when she threw him a look of utter dismay he paus
# Original:
# Effortlessly , his knee slid to part her legs , but when she threw him a look of utter dismay he paus
# Augmented Text:
# ['Effortlessly, Trixie_Whitley abductor_muscle stumbled to part her legs, but invariably Sirny threw him a look of utter outcry ÔI paus']
# The commercial ethic meant some deterioration in standards , while the cutbacks in the Overseas News department , one of the glories of Bush House , caused much dismay in the public communications wor
# Original:
# The commercial ethic meant some deterioration in standards , while the cutbacks in the Overseas News department , one of the glories of Bush House , caused much dismay in the public communications wor
# Augmented Text:
# ['Additionally commercial ethic meant some Deteriorating duringthe specification, besides the cutbacks in the Overseas Ana_Tintocalis_KPBS department, one of the glories of Bush House, caused much outrage near the taxpayer_dollars communications gilbert']
# This caused a good deal of consternation and dismay in Westminst
# Original:
# This caused a good deal of consternation and dismay in Westminst
# Augmented Text:
# ['An exacerbating a Vincent_Lecavalier_Stamkos deal of disdain and dismay in Westminst']
# And it was equally insistent that a policy of retreat would cause dismay in Washington , thereby diminishing Britain 's ability to exert influence over American poli
# Original:
# And it was equally insistent that a policy of retreat would cause dismay in Washington , thereby diminishing Britain 's ability to exert influence over American poli
# Augmented Text:
# ["And PIET_VILJOEN_Yes andwas equally insistent that a poli_cies of LifeWay_Ridgecrest_Conference would cause irritation in Gerald_Martineau, thereby diminishing United_Kingdom ' s effectively to exert undue_influence over American poli"]
# Floyd Patterson has expressed dismay over the current treatme
# Original:
# Floyd Patterson has expressed dismay over the current treatme
# Augmented Text:
# ['Floyd Dodson hasbeen expressed dismay over full current treatme']
# Edouard looked at him , and felt a sickening dism
# Original:
# Edouard looked at him , and felt a sickening dism
# Augmented Text:
# ['Edouard visably Tues._Thurs him, and felt a depraved dism']
# When Tina and the children moved into the School , Cecilia felt both dismay and guilty reli
# Original:
# When Tina and the children moved into the School , Cecilia felt both dismay and guilty reli
# Augmented Text:
# ['When Amanda and the children opened into _the School, Josephine felt mulitiple grumbling and guilty reli']
# But he felt ` dismay and sorrow for so many people in our country who do not share this personal good fortune
# Original:
# But he felt ` dismay and sorrow for so many people in our country who do not share this personal good fortune
# Augmented Text:
# ['But he felt ` collective_yawn and deepest_regrets provide so many people in our country Rebecca_Grignon obstruct_petty_larceny enough share this Ellen_Roseman_writes good fortune']
# They stared at one another in dismay , the sad , small wickedness of their friends and neighbours strewn around their minds like dirty confetti from a party long pa
# Original:
# They stared at one another in dismay , the sad , small wickedness of their friends and neighbours strewn around their minds like dirty confetti from a party long pa
# Augmented Text:
# ['Generally stared at one another in dismay, proverbial poignant, small wickedness of their cousins_aunts_uncles and neighbours strewn around their mouths like mucky balloons_streamers from a fledgling_Wildrose_Alliance Lengthy pa']
# Cleo stared at the contents with dism
# Original:
# Cleo stared at the contents with dism
# Augmented Text:
# ['Jazzie smiling Raddison_Hotel the contents with dism']
# Melissa stared at her friend in dism
# Original:
# Melissa stared at her friend in dism
# Augmented Text:
# ['Melissa gestured_toward at Madassa friend first dism']
# Successive state elections have seen the governing parties pummelled by a dismayed electora
# Original:
# Successive state elections have seen the governing parties pummelled by a dismayed electora
# Augmented Text:
# ['These districts Chapra_Lok_Sabha have seen the Scott_Getzschman_insisted parties pummelled by a dismayed electora']
# Vincent was irritated but not dismay
# Original:
# Vincent was irritated but not dismay
# Augmented Text:
# ['Vincent originally irritated but not concern']
# Kendall-Hume turned back to face the dismayed coup
# Original:
# Kendall-Hume turned back to face the dismayed coup
# Augmented Text:
# ['Kendall - Hume turned enziguiri_kick to face all appalled coup']
# I am dismayed , but not surpris
# Original:
# I am dismayed , but not surpris
# Augmented Text:
# ['I am dismayed, only Victor_Bout_Somsak comentarios']
